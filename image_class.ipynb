# %%
import os
import shutil

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import classification_report, f1_score

import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.layers import Activation, Dropout, Flatten, Dense 
from keras.layers import AveragePooling2D, MaxPooling2D, Convolution2D, GlobalAveragePooling2D
from keras.models import Model
from keras.layers import Dense, Input, Flatten, Dropout, MaxPooling2D, BatchNormalization, GlobalAveragePooling2D, Activation, Concatenate
from keras import Sequential

from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.applications.xception import Xception
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet import ResNet101
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg19 import VGG19

# %%
main_directory = 'apple_jpeg_images'
split_directory = 'split'

os.makedirs(split_directory, exist_ok=True)
class_directories = [f for f in os.listdir(main_directory) if os.path.isdir(os.path.join(main_directory, f))]

# %%
train_ratio = 0.7
validation_ratio = 0.15
test_ratio = 0.15

# %%
train_directory = os.path.join(split_directory, 'train')
validation_directory = os.path.join(split_directory, 'validation')
test_directory = os.path.join(split_directory, 'test')

os.makedirs(train_directory, exist_ok=True)
os.makedirs(validation_directory, exist_ok=True)
os.makedirs(test_directory, exist_ok=True)

# %%
# Iterate through each class directory and move images to the appropriate split
for class_dir in class_directories:
    class_path = os.path.join(main_directory, class_dir)
    files = os.listdir(class_path)
    num_samples = len(files)
    
    num_train = int(train_ratio * num_samples)
    num_validation = int(validation_ratio * num_samples)
    
    train_samples = files[:num_train]
    validation_samples = files[num_train:num_train + num_validation]
    test_samples = files[num_train + num_validation:]
    
    for file in train_samples:
        src = os.path.join(class_path, file)
        dst = os.path.join(train_directory, class_dir, file)
        os.makedirs(os.path.dirname(dst), exist_ok=True)
        shutil.move(src, dst)
    
    for file in validation_samples:
        src = os.path.join(class_path, file)
        dst = os.path.join(validation_directory, class_dir, file)
        os.makedirs(os.path.dirname(dst), exist_ok=True)
        shutil.move(src, dst)
    
 
    for file in test_samples:
        src = os.path.join(class_path, file)
        dst = os.path.join(test_directory, class_dir, file)
        os.makedirs(os.path.dirname(dst), exist_ok=True)
        shutil.move(src, dst)

# %%
input_shape = (224, 224, 3)
batch_size = 32

# %%
datagen = ImageDataGenerator(rescale=1./255)

generator = datagen.flow_from_directory(
    train_directory,  
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',  
    shuffle=False  # Set to False to maintain class-wise order
)

# Get the class labels and their corresponding indices
class_indices = generator.class_indices
num_classes = len(class_indices.items())

for class_name, class_idx in class_indices.items():
    class_count = (generator.classes == class_idx).sum()
    print(f'Class {class_name}: {class_count} samples')
# Out:
# Found 2380 images belonging to 4 classes.
# Class healthy: 595 samples
# Class powdery_mildew: 595 samples
# Class rust: 595 samples
# Class scab: 595 samples

# %%
num_images_per_class = 2  

for class_name, class_idx in class_indices.items():
    class_count = (generator.classes == class_idx).sum()
    
    if class_count > 0:
        print(f'Class {class_name}: {class_count} samples')
        plt.figure(figsize=(10, 5))
        
        # Retrieve the first num_images_per_class images from the generator
        images_to_display = []
        for i, (image, label) in enumerate(generator):
            if label[0, class_idx] == 1:
                images_to_display.append(image[0])
            if len(images_to_display) >= num_images_per_class:
                break
        
        for i, img in enumerate(images_to_display):
            plt.subplot(1, num_images_per_class, i + 1)
            plt.imshow(img)
            plt.title(f'Image {i + 1}')
            plt.axis('off')
        
        plt.show()
# Out:
# Class healthy: 595 samples
# Class powdery_mildew: 595 samples
# Class rust: 595 samples
# Class scab: 595 samples

# %%
# Data Augmentation for train
train_datagen = ImageDataGenerator(
    rescale=1.0/255.0,  # Rescale pixel values to [0, 1]
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

test_datagen = ImageDataGenerator(rescale=1.0/255.0)

train_generator = train_datagen.flow_from_directory(
    train_directory,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical'
)

validation_generator = test_datagen.flow_from_directory(
    validation_directory,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    test_directory,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 2380 images belonging to 4 classes.
# Found 508 images belonging to 4 classes.
# Found 512 images belonging to 4 classes.

# %%
epochs = 150
learning_rate=0.0001

adam = Adam(lr=learning_rate)
sgd = SGD(lr=learning_rate, momentum=0.9, nesterov=True)

model_checkpoint = ModelCheckpoint('best_model.h5', save_best_only=True, verbose=1)
early_stopping = EarlyStopping(patience=25, restore_best_weights=True)
lrr = ReduceLROnPlateau(monitor='val_accuracy', factor=.01, patience=3, min_lr=1e-5) #change learning rATE  to get the best result
# Out:
# C:\Users\Razaq\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\optimizer_v2\gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %%
model = Sequential()

# Convolutional layers
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
#model.add(BatchNormalization()) 
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu'))
#model.add(BatchNormalization()) 
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu'))
#model.add(BatchNormalization()) 
model.add(MaxPooling2D((2, 2)))


# Flatten the feature maps
model.add(Flatten())

# Fully connected layers
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(num_classes, activation='softmax'))

model.compile(optimizer=sgd, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,
    callbacks=[model_checkpoint, early_stopping, lrr]
)
# Out:
# Epoch 1/150
# 74/74 [==============================] - ETA: 0s - loss: 1.3847 - accuracy: 0.2538
# Epoch 1: val_loss improved from inf to 1.38012, saving model to best_model.h5
# 74/74 [==============================] - 73s 984ms/step - loss: 1.3847 - accuracy: 0.2538 - val_loss: 1.3801 - val_accuracy: 0.2771 - lr: 1.0000e-04
# Epoch 2/150
# 74/74 [==============================] - ETA: 0s - loss: 1.3813 - accuracy: 0.2739
# Epoch 2: val_loss improved from 1.38012 to 1.37462, saving model to best_model.h5
# 74/74 [==============================] - 73s 984ms/step - loss: 1.3813 - accuracy: 0.2739 - val_loss: 1.3746 - val_accuracy: 0.2604 - lr: 1.0000e-04
# Epoch 3/150
# 74/74 [==============================] - ETA: 0s - loss: 1.3775 - accuracy: 0.2926
# Epoch 3: val_loss improved from 1.37462 to 1.36906, saving model to best_model.h5
# 74/74 [==============================] - 73s 978ms/step - loss: 1.3775 - accuracy: 0.2926 - val_loss: 1.3691 - val_accuracy: 0.3042 - lr: 1.0000e-04
# Epoch 4/150
# 74/74 [==============================] - ETA: 0s - loss: 1.3701 - accuracy: 0.3113
# Epoch 4: val_loss improved from 1.36906 to 1.35914, saving model to best_model.h5
# 74/74 [==============================] - 73s 989ms/step - loss: 1.3701 - accuracy: 0.3113 - val_loss: 1.3591 - val_accuracy: 0.3604 - lr: 1.0000e-04
# Epoch 5/150
# 74/74 [==============================] - ETA: 0s - loss: 1.3688 - accuracy: 0.3258
# Epoch 5: val_loss improved from 1.35914 to 1.35293, saving model to best_model.h5
# 74/74 [==============================] - 74s 994ms/step - loss: 1.3688 - accuracy: 0.3258 - val_loss: 1.3529 - val_accuracy: 0.4375 - lr: 1.0000e-04
# Epoch 6/150
# 74/74 [==============================] - ETA: 0s - loss: 1.3628 - accuracy: 0.3488
# Epoch 6: val_loss improved from 1.35293 to 1.34468, saving model to best_model.h5
# 74/74 [==============================] - 74s 990ms/step - loss: 1.3628 - accuracy: 0.3488 - val_loss: 1.3447 - val_accuracy: 0.4500 - lr: 1.0000e-04
# Epoch 7/150
# 74/74 [==============================] - ETA: 0s - loss: 1.3543 - accuracy: 0.3667
# Epoch 7: val_loss improved from 1.34468 to 1.33471, saving model to best_model.h5
# 74/74 [==============================] - 73s 979ms/step - loss: 1.3543 - accuracy: 0.3667 - val_loss: 1.3347 - val_accuracy: 0.4583 - lr: 1.0000e-04
# Epoch 8/150
# 74/74 [==============================] - ETA: 0s - loss: 1.3439 - accuracy: 0.3761
# Epoch 8: val_loss improved from 1.33471 to 1.32278, saving model to best_model.h5
# 74/74 [==============================] - 73s 985ms/step - loss: 1.3439 - accuracy: 0.3761 - val_loss: 1.3228 - val_accuracy: 0.4396 - lr: 1.0000e-04
# Epoch 9/150
# 74/74 [==============================] - ETA: 0s - loss: 1.3337 - accuracy: 0.4106
# Epoch 9: val_loss improved from 1.32278 to 1.30995, saving model to best_model.h5
# 74/74 [==============================] - 73s 986ms/step - loss: 1.3337 - accuracy: 0.4106 - val_loss: 1.3100 - val_accuracy: 0.4708 - lr: 1.0000e-04
# Epoch 10/150
# 74/74 [==============================] - ETA: 0s - loss: 1.3222 - accuracy: 0.4229
# Epoch 10: val_loss improved from 1.30995 to 1.28793, saving model to best_model.h5
# 74/74 [==============================] - 79s 1s/step - loss: 1.3222 - accuracy: 0.4229 - val_loss: 1.2879 - val_accuracy: 0.5125 - lr: 1.0000e-04
# Epoch 11/150
# 74/74 [==============================] - ETA: 0s - loss: 1.3085 - accuracy: 0.4284
# Epoch 11: val_loss improved from 1.28793 to 1.27085, saving model to best_model.h5
# 74/74 [==============================] - 76s 1s/step - loss: 1.3085 - accuracy: 0.4284 - val_loss: 1.2709 - val_accuracy: 0.4542 - lr: 1.0000e-04
# Epoch 12/150
# 74/74 [==============================] - ETA: 0s - loss: 1.2869 - accuracy: 0.4497
# Epoch 12: val_loss improved from 1.27085 to 1.24998, saving model to best_model.h5
# 74/74 [==============================] - 72s 975ms/step - loss: 1.2869 - accuracy: 0.4497 - val_loss: 1.2500 - val_accuracy: 0.4458 - lr: 1.0000e-04
# Epoch 13/150
# 74/74 [==============================] - ETA: 0s - loss: 1.2673 - accuracy: 0.4591
# Epoch 13: val_loss improved from 1.24998 to 1.21757, saving model to best_model.h5
# 74/74 [==============================] - 73s 982ms/step - loss: 1.2673 - accuracy: 0.4591 - val_loss: 1.2176 - val_accuracy: 0.5604 - lr: 1.0000e-04
# Epoch 14/150
# 74/74 [==============================] - ETA: 0s - loss: 1.2460 - accuracy: 0.4638
# Epoch 14: val_loss improved from 1.21757 to 1.18248, saving model to best_model.h5
# 74/74 [==============================] - 73s 980ms/step - loss: 1.2460 - accuracy: 0.4638 - val_loss: 1.1825 - val_accuracy: 0.5938 - lr: 1.0000e-04
# Epoch 15/150
# 74/74 [==============================] - ETA: 0s - loss: 1.2140 - accuracy: 0.4872
# Epoch 15: val_loss improved from 1.18248 to 1.15235, saving model to best_model.h5
# 74/74 [==============================] - 73s 976ms/step - loss: 1.2140 - accuracy: 0.4872 - val_loss: 1.1523 - val_accuracy: 0.5875 - lr: 1.0000e-04
# Epoch 16/150
# 74/74 [==============================] - ETA: 0s - loss: 1.1897 - accuracy: 0.4949
# Epoch 16: val_loss improved from 1.15235 to 1.12582, saving model to best_model.h5
# 74/74 [==============================] - 72s 974ms/step - loss: 1.1897 - accuracy: 0.4949 - val_loss: 1.1258 - val_accuracy: 0.5375 - lr: 1.0000e-04
# Epoch 17/150
# 74/74 [==============================] - ETA: 0s - loss: 1.1636 - accuracy: 0.4953
# Epoch 17: val_loss improved from 1.12582 to 1.09310, saving model to best_model.h5
# 74/74 [==============================] - 85s 1s/step - loss: 1.1636 - accuracy: 0.4953 - val_loss: 1.0931 - val_accuracy: 0.6271 - lr: 1.0000e-04
# Epoch 18/150
# 74/74 [==============================] - ETA: 0s - loss: 1.1327 - accuracy: 0.5413
# Epoch 18: val_loss improved from 1.09310 to 1.06853, saving model to best_model.h5
# 74/74 [==============================] - 86s 1s/step - loss: 1.1327 - accuracy: 0.5413 - val_loss: 1.0685 - val_accuracy: 0.6062 - lr: 1.0000e-04
# Epoch 19/150
# 74/74 [==============================] - ETA: 0s - loss: 1.1102 - accuracy: 0.5209
# Epoch 19: val_loss improved from 1.06853 to 1.02959, saving model to best_model.h5
# 74/74 [==============================] - 86s 1s/step - loss: 1.1102 - accuracy: 0.5209 - val_loss: 1.0296 - val_accuracy: 0.6354 - lr: 1.0000e-04
# Epoch 20/150
# 74/74 [==============================] - ETA: 0s - loss: 1.1034 - accuracy: 0.5187
# Epoch 20: val_loss improved from 1.02959 to 1.01863, saving model to best_model.h5
# 74/74 [==============================] - 85s 1s/step - loss: 1.1034 - accuracy: 0.5187 - val_loss: 1.0186 - val_accuracy: 0.6500 - lr: 1.0000e-04
# Epoch 21/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0780 - accuracy: 0.5507
# Epoch 21: val_loss improved from 1.01863 to 1.00096, saving model to best_model.h5
# 74/74 [==============================] - 85s 1s/step - loss: 1.0780 - accuracy: 0.5507 - val_loss: 1.0010 - val_accuracy: 0.5625 - lr: 1.0000e-04
# Epoch 22/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0655 - accuracy: 0.5558
# Epoch 22: val_loss improved from 1.00096 to 0.97883, saving model to best_model.h5
# 74/74 [==============================] - 85s 1s/step - loss: 1.0655 - accuracy: 0.5558 - val_loss: 0.9788 - val_accuracy: 0.6354 - lr: 1.0000e-04
# Epoch 23/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0582 - accuracy: 0.5409
# Epoch 23: val_loss improved from 0.97883 to 0.96121, saving model to best_model.h5
# 74/74 [==============================] - 85s 1s/step - loss: 1.0582 - accuracy: 0.5409 - val_loss: 0.9612 - val_accuracy: 0.6396 - lr: 1.0000e-04
# Epoch 24/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0478 - accuracy: 0.5524
# Epoch 24: val_loss improved from 0.96121 to 0.95051, saving model to best_model.h5
# 74/74 [==============================] - 85s 1s/step - loss: 1.0478 - accuracy: 0.5524 - val_loss: 0.9505 - val_accuracy: 0.6313 - lr: 1.0000e-05
# Epoch 25/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0482 - accuracy: 0.5503
# Epoch 25: val_loss did not improve from 0.95051
# 74/74 [==============================] - 83s 1s/step - loss: 1.0482 - accuracy: 0.5503 - val_loss: 0.9553 - val_accuracy: 0.6354 - lr: 1.0000e-05
# Epoch 26/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0522 - accuracy: 0.5430
# Epoch 26: val_loss improved from 0.95051 to 0.94907, saving model to best_model.h5
# 74/74 [==============================] - 82s 1s/step - loss: 1.0522 - accuracy: 0.5430 - val_loss: 0.9491 - val_accuracy: 0.6417 - lr: 1.0000e-05
# Epoch 27/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0404 - accuracy: 0.5473
# Epoch 27: val_loss did not improve from 0.94907
# 74/74 [==============================] - 84s 1s/step - loss: 1.0404 - accuracy: 0.5473 - val_loss: 0.9539 - val_accuracy: 0.6271 - lr: 1.0000e-05
# Epoch 28/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0430 - accuracy: 0.5511
# Epoch 28: val_loss improved from 0.94907 to 0.94744, saving model to best_model.h5
# 74/74 [==============================] - 89s 1s/step - loss: 1.0430 - accuracy: 0.5511 - val_loss: 0.9474 - val_accuracy: 0.6354 - lr: 1.0000e-05
# Epoch 29/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0339 - accuracy: 0.5579
# Epoch 29: val_loss improved from 0.94744 to 0.94599, saving model to best_model.h5
# 74/74 [==============================] - 85s 1s/step - loss: 1.0339 - accuracy: 0.5579 - val_loss: 0.9460 - val_accuracy: 0.6417 - lr: 1.0000e-05
# Epoch 30/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0367 - accuracy: 0.5549
# Epoch 30: val_loss improved from 0.94599 to 0.94566, saving model to best_model.h5
# 74/74 [==============================] - 85s 1s/step - loss: 1.0367 - accuracy: 0.5549 - val_loss: 0.9457 - val_accuracy: 0.6271 - lr: 1.0000e-05
# Epoch 31/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0423 - accuracy: 0.5456
# Epoch 31: val_loss improved from 0.94566 to 0.94527, saving model to best_model.h5
# 74/74 [==============================] - 85s 1s/step - loss: 1.0423 - accuracy: 0.5456 - val_loss: 0.9453 - val_accuracy: 0.6292 - lr: 1.0000e-05
# Epoch 32/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0276 - accuracy: 0.5635
# Epoch 32: val_loss improved from 0.94527 to 0.94355, saving model to best_model.h5
# 74/74 [==============================] - 82s 1s/step - loss: 1.0276 - accuracy: 0.5635 - val_loss: 0.9435 - val_accuracy: 0.6438 - lr: 1.0000e-05
# Epoch 33/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0372 - accuracy: 0.5605
# Epoch 33: val_loss improved from 0.94355 to 0.94185, saving model to best_model.h5
# 74/74 [==============================] - 80s 1s/step - loss: 1.0372 - accuracy: 0.5605 - val_loss: 0.9419 - val_accuracy: 0.6438 - lr: 1.0000e-05
# Epoch 34/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0341 - accuracy: 0.5754
# Epoch 34: val_loss did not improve from 0.94185
# 74/74 [==============================] - 79s 1s/step - loss: 1.0341 - accuracy: 0.5754 - val_loss: 0.9497 - val_accuracy: 0.6313 - lr: 1.0000e-05
# Epoch 35/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0295 - accuracy: 0.5779
# Epoch 35: val_loss improved from 0.94185 to 0.94090, saving model to best_model.h5
# 74/74 [==============================] - 82s 1s/step - loss: 1.0295 - accuracy: 0.5779 - val_loss: 0.9409 - val_accuracy: 0.6333 - lr: 1.0000e-05
# Epoch 36/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0329 - accuracy: 0.5703
# Epoch 36: val_loss did not improve from 0.94090
# 74/74 [==============================] - 78s 1s/step - loss: 1.0329 - accuracy: 0.5703 - val_loss: 0.9416 - val_accuracy: 0.6354 - lr: 1.0000e-05
# Epoch 37/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0219 - accuracy: 0.5596
# Epoch 37: val_loss improved from 0.94090 to 0.94025, saving model to best_model.h5
# 74/74 [==============================] - 80s 1s/step - loss: 1.0219 - accuracy: 0.5596 - val_loss: 0.9402 - val_accuracy: 0.6313 - lr: 1.0000e-05
# Epoch 38/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0256 - accuracy: 0.5579
# Epoch 38: val_loss improved from 0.94025 to 0.93750, saving model to best_model.h5
# 74/74 [==============================] - 74s 994ms/step - loss: 1.0256 - accuracy: 0.5579 - val_loss: 0.9375 - val_accuracy: 0.6417 - lr: 1.0000e-05
# Epoch 39/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0284 - accuracy: 0.5694
# Epoch 39: val_loss improved from 0.93750 to 0.93585, saving model to best_model.h5
# 74/74 [==============================] - 79s 1s/step - loss: 1.0284 - accuracy: 0.5694 - val_loss: 0.9359 - val_accuracy: 0.6271 - lr: 1.0000e-05
# Epoch 40/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0226 - accuracy: 0.5720
# Epoch 40: val_loss did not improve from 0.93585
# 74/74 [==============================] - 72s 963ms/step - loss: 1.0226 - accuracy: 0.5720 - val_loss: 0.9390 - val_accuracy: 0.6354 - lr: 1.0000e-05
# Epoch 41/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0234 - accuracy: 0.5707
# Epoch 41: val_loss improved from 0.93585 to 0.93509, saving model to best_model.h5
# 74/74 [==============================] - 72s 972ms/step - loss: 1.0234 - accuracy: 0.5707 - val_loss: 0.9351 - val_accuracy: 0.6333 - lr: 1.0000e-05
# Epoch 42/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0197 - accuracy: 0.5775
# Epoch 42: val_loss improved from 0.93509 to 0.92842, saving model to best_model.h5
# 74/74 [==============================] - 73s 984ms/step - loss: 1.0197 - accuracy: 0.5775 - val_loss: 0.9284 - val_accuracy: 0.6292 - lr: 1.0000e-05
# Epoch 43/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0172 - accuracy: 0.5739
# Epoch 43: val_loss did not improve from 0.92842
# 74/74 [==============================] - 72s 964ms/step - loss: 1.0172 - accuracy: 0.5739 - val_loss: 0.9295 - val_accuracy: 0.6375 - lr: 1.0000e-05
# Epoch 44/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0297 - accuracy: 0.5677
# Epoch 44: val_loss did not improve from 0.92842
# 74/74 [==============================] - 71s 953ms/step - loss: 1.0297 - accuracy: 0.5677 - val_loss: 0.9353 - val_accuracy: 0.6333 - lr: 1.0000e-05
# Epoch 45/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0190 - accuracy: 0.5741
# Epoch 45: val_loss improved from 0.92842 to 0.92838, saving model to best_model.h5
# 74/74 [==============================] - 72s 974ms/step - loss: 1.0190 - accuracy: 0.5741 - val_loss: 0.9284 - val_accuracy: 0.6417 - lr: 1.0000e-05
# Epoch 46/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0242 - accuracy: 0.5579
# Epoch 46: val_loss improved from 0.92838 to 0.92684, saving model to best_model.h5
# 74/74 [==============================] - 72s 973ms/step - loss: 1.0242 - accuracy: 0.5579 - val_loss: 0.9268 - val_accuracy: 0.6313 - lr: 1.0000e-05
# Epoch 47/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0090 - accuracy: 0.5826
# Epoch 47: val_loss improved from 0.92684 to 0.92231, saving model to best_model.h5
# 74/74 [==============================] - 73s 977ms/step - loss: 1.0090 - accuracy: 0.5826 - val_loss: 0.9223 - val_accuracy: 0.6375 - lr: 1.0000e-05
# Epoch 48/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0305 - accuracy: 0.5681
# Epoch 48: val_loss improved from 0.92231 to 0.92062, saving model to best_model.h5
# 74/74 [==============================] - 73s 986ms/step - loss: 1.0305 - accuracy: 0.5681 - val_loss: 0.9206 - val_accuracy: 0.6375 - lr: 1.0000e-05
# Epoch 49/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0200 - accuracy: 0.5660
# Epoch 49: val_loss did not improve from 0.92062
# 74/74 [==============================] - 72s 964ms/step - loss: 1.0200 - accuracy: 0.5660 - val_loss: 0.9253 - val_accuracy: 0.6354 - lr: 1.0000e-05
# Epoch 50/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0076 - accuracy: 0.5839
# Epoch 50: val_loss did not improve from 0.92062
# 74/74 [==============================] - 71s 958ms/step - loss: 1.0076 - accuracy: 0.5839 - val_loss: 0.9262 - val_accuracy: 0.6354 - lr: 1.0000e-05
# Epoch 51/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0085 - accuracy: 0.5813
# Epoch 51: val_loss did not improve from 0.92062
# 74/74 [==============================] - 73s 986ms/step - loss: 1.0085 - accuracy: 0.5813 - val_loss: 0.9206 - val_accuracy: 0.6313 - lr: 1.0000e-05
# Epoch 52/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0098 - accuracy: 0.5775
# Epoch 52: val_loss did not improve from 0.92062
# 74/74 [==============================] - 71s 961ms/step - loss: 1.0098 - accuracy: 0.5775 - val_loss: 0.9234 - val_accuracy: 0.6417 - lr: 1.0000e-05
# Epoch 53/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0123 - accuracy: 0.5686
# Epoch 53: val_loss improved from 0.92062 to 0.91387, saving model to best_model.h5
# 74/74 [==============================] - 73s 983ms/step - loss: 1.0123 - accuracy: 0.5686 - val_loss: 0.9139 - val_accuracy: 0.6396 - lr: 1.0000e-05
# Epoch 54/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0151 - accuracy: 0.5664
# Epoch 54: val_loss did not improve from 0.91387
# 74/74 [==============================] - 72s 962ms/step - loss: 1.0151 - accuracy: 0.5664 - val_loss: 0.9298 - val_accuracy: 0.6250 - lr: 1.0000e-05
# Epoch 55/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0116 - accuracy: 0.5733
# Epoch 55: val_loss did not improve from 0.91387
# 74/74 [==============================] - 71s 957ms/step - loss: 1.0116 - accuracy: 0.5733 - val_loss: 0.9286 - val_accuracy: 0.6292 - lr: 1.0000e-05
# Epoch 56/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0136 - accuracy: 0.5660
# Epoch 56: val_loss did not improve from 0.91387
# 74/74 [==============================] - 71s 954ms/step - loss: 1.0136 - accuracy: 0.5660 - val_loss: 0.9140 - val_accuracy: 0.6438 - lr: 1.0000e-05
# Epoch 57/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0129 - accuracy: 0.5762
# Epoch 57: val_loss did not improve from 0.91387
# 74/74 [==============================] - 71s 952ms/step - loss: 1.0129 - accuracy: 0.5762 - val_loss: 0.9239 - val_accuracy: 0.6271 - lr: 1.0000e-05
# Epoch 58/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0077 - accuracy: 0.5745
# Epoch 58: val_loss did not improve from 0.91387
# 74/74 [==============================] - 71s 955ms/step - loss: 1.0077 - accuracy: 0.5745 - val_loss: 0.9183 - val_accuracy: 0.6354 - lr: 1.0000e-05
# Epoch 59/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0149 - accuracy: 0.5716
# Epoch 59: val_loss did not improve from 0.91387
# 74/74 [==============================] - 71s 956ms/step - loss: 1.0149 - accuracy: 0.5716 - val_loss: 0.9143 - val_accuracy: 0.6292 - lr: 1.0000e-05
# Epoch 60/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9995 - accuracy: 0.5835
# Epoch 60: val_loss did not improve from 0.91387
# 74/74 [==============================] - 73s 974ms/step - loss: 0.9995 - accuracy: 0.5835 - val_loss: 0.9149 - val_accuracy: 0.6458 - lr: 1.0000e-05
# Epoch 61/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0003 - accuracy: 0.5805
# Epoch 61: val_loss did not improve from 0.91387
# 74/74 [==============================] - 71s 960ms/step - loss: 1.0003 - accuracy: 0.5805 - val_loss: 0.9150 - val_accuracy: 0.6417 - lr: 1.0000e-05
# Epoch 62/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0117 - accuracy: 0.5707
# Epoch 62: val_loss did not improve from 0.91387
# 74/74 [==============================] - 71s 960ms/step - loss: 1.0117 - accuracy: 0.5707 - val_loss: 0.9230 - val_accuracy: 0.6250 - lr: 1.0000e-05
# Epoch 63/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0083 - accuracy: 0.5779
# Epoch 63: val_loss did not improve from 0.91387
# 74/74 [==============================] - 71s 952ms/step - loss: 1.0083 - accuracy: 0.5779 - val_loss: 0.9208 - val_accuracy: 0.6417 - lr: 1.0000e-05
# Epoch 64/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9978 - accuracy: 0.5899
# Epoch 64: val_loss improved from 0.91387 to 0.90427, saving model to best_model.h5
# 74/74 [==============================] - 74s 1s/step - loss: 0.9978 - accuracy: 0.5899 - val_loss: 0.9043 - val_accuracy: 0.6479 - lr: 1.0000e-05
# Epoch 65/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9939 - accuracy: 0.5924
# Epoch 65: val_loss did not improve from 0.90427
# 74/74 [==============================] - 72s 967ms/step - loss: 0.9939 - accuracy: 0.5924 - val_loss: 0.9067 - val_accuracy: 0.6438 - lr: 1.0000e-05
# Epoch 66/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9974 - accuracy: 0.5860
# Epoch 66: val_loss improved from 0.90427 to 0.90169, saving model to best_model.h5
# 74/74 [==============================] - 72s 976ms/step - loss: 0.9974 - accuracy: 0.5860 - val_loss: 0.9017 - val_accuracy: 0.6313 - lr: 1.0000e-05
# Epoch 67/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0012 - accuracy: 0.5779
# Epoch 67: val_loss did not improve from 0.90169
# 74/74 [==============================] - 71s 949ms/step - loss: 1.0012 - accuracy: 0.5779 - val_loss: 0.9101 - val_accuracy: 0.6313 - lr: 1.0000e-05
# Epoch 68/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9964 - accuracy: 0.5796
# Epoch 68: val_loss did not improve from 0.90169
# 74/74 [==============================] - 71s 956ms/step - loss: 0.9964 - accuracy: 0.5796 - val_loss: 0.9019 - val_accuracy: 0.6417 - lr: 1.0000e-05
# Epoch 69/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0018 - accuracy: 0.5852
# Epoch 69: val_loss did not improve from 0.90169
# 74/74 [==============================] - 71s 953ms/step - loss: 1.0018 - accuracy: 0.5852 - val_loss: 0.9054 - val_accuracy: 0.6417 - lr: 1.0000e-05
# Epoch 70/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0038 - accuracy: 0.5686
# Epoch 70: val_loss did not improve from 0.90169
# 74/74 [==============================] - 71s 961ms/step - loss: 1.0038 - accuracy: 0.5686 - val_loss: 0.9053 - val_accuracy: 0.6479 - lr: 1.0000e-05
# Epoch 71/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9934 - accuracy: 0.5899
# Epoch 71: val_loss did not improve from 0.90169
# 74/74 [==============================] - 71s 952ms/step - loss: 0.9934 - accuracy: 0.5899 - val_loss: 0.9134 - val_accuracy: 0.6354 - lr: 1.0000e-05
# Epoch 72/150
# 74/74 [==============================] - ETA: 0s - loss: 1.0003 - accuracy: 0.5805
# Epoch 72: val_loss did not improve from 0.90169
# 74/74 [==============================] - 71s 951ms/step - loss: 1.0003 - accuracy: 0.5805 - val_loss: 0.9142 - val_accuracy: 0.6333 - lr: 1.0000e-05
# Epoch 73/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9830 - accuracy: 0.5894
# Epoch 73: val_loss did not improve from 0.90169
# 74/74 [==============================] - 71s 954ms/step - loss: 0.9830 - accuracy: 0.5894 - val_loss: 0.9069 - val_accuracy: 0.6396 - lr: 1.0000e-05
# Epoch 74/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9934 - accuracy: 0.5716
# Epoch 74: val_loss did not improve from 0.90169
# 74/74 [==============================] - 71s 959ms/step - loss: 0.9934 - accuracy: 0.5716 - val_loss: 0.9065 - val_accuracy: 0.6375 - lr: 1.0000e-05
# Epoch 75/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9970 - accuracy: 0.5767
# Epoch 75: val_loss improved from 0.90169 to 0.89548, saving model to best_model.h5
# 74/74 [==============================] - 72s 972ms/step - loss: 0.9970 - accuracy: 0.5767 - val_loss: 0.8955 - val_accuracy: 0.6417 - lr: 1.0000e-05
# Epoch 76/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9813 - accuracy: 0.5937
# Epoch 76: val_loss did not improve from 0.89548
# 74/74 [==============================] - 73s 988ms/step - loss: 0.9813 - accuracy: 0.5937 - val_loss: 0.9090 - val_accuracy: 0.6458 - lr: 1.0000e-05
# Epoch 77/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9939 - accuracy: 0.5809
# Epoch 77: val_loss did not improve from 0.89548
# 74/74 [==============================] - 76s 1s/step - loss: 0.9939 - accuracy: 0.5809 - val_loss: 0.9039 - val_accuracy: 0.6396 - lr: 1.0000e-05
# Epoch 78/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9953 - accuracy: 0.5822
# Epoch 78: val_loss improved from 0.89548 to 0.89521, saving model to best_model.h5
# 74/74 [==============================] - 77s 1s/step - loss: 0.9953 - accuracy: 0.5822 - val_loss: 0.8952 - val_accuracy: 0.6458 - lr: 1.0000e-05
# Epoch 79/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9902 - accuracy: 0.5886
# Epoch 79: val_loss did not improve from 0.89521
# 74/74 [==============================] - 76s 1s/step - loss: 0.9902 - accuracy: 0.5886 - val_loss: 0.9052 - val_accuracy: 0.6354 - lr: 1.0000e-05
# Epoch 80/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9873 - accuracy: 0.5971
# Epoch 80: val_loss did not improve from 0.89521
# 74/74 [==============================] - 77s 1s/step - loss: 0.9873 - accuracy: 0.5971 - val_loss: 0.9060 - val_accuracy: 0.6333 - lr: 1.0000e-05
# Epoch 81/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9933 - accuracy: 0.5839
# Epoch 81: val_loss did not improve from 0.89521
# 74/74 [==============================] - 77s 1s/step - loss: 0.9933 - accuracy: 0.5839 - val_loss: 0.8953 - val_accuracy: 0.6583 - lr: 1.0000e-05
# Epoch 82/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9889 - accuracy: 0.5737
# Epoch 82: val_loss improved from 0.89521 to 0.88575, saving model to best_model.h5
# 74/74 [==============================] - 77s 1s/step - loss: 0.9889 - accuracy: 0.5737 - val_loss: 0.8857 - val_accuracy: 0.6562 - lr: 1.0000e-05
# Epoch 83/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9859 - accuracy: 0.6005
# Epoch 83: val_loss did not improve from 0.88575
# 74/74 [==============================] - 77s 1s/step - loss: 0.9859 - accuracy: 0.6005 - val_loss: 0.8988 - val_accuracy: 0.6479 - lr: 1.0000e-05
# Epoch 84/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9846 - accuracy: 0.5958
# Epoch 84: val_loss did not improve from 0.88575
# 74/74 [==============================] - 76s 1s/step - loss: 0.9846 - accuracy: 0.5958 - val_loss: 0.8923 - val_accuracy: 0.6479 - lr: 1.0000e-05
# Epoch 85/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9890 - accuracy: 0.5809
# Epoch 85: val_loss did not improve from 0.88575
# 74/74 [==============================] - 78s 1s/step - loss: 0.9890 - accuracy: 0.5809 - val_loss: 0.8923 - val_accuracy: 0.6479 - lr: 1.0000e-05
# Epoch 86/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9784 - accuracy: 0.5886
# Epoch 86: val_loss did not improve from 0.88575
# 74/74 [==============================] - 76s 1s/step - loss: 0.9784 - accuracy: 0.5886 - val_loss: 0.8883 - val_accuracy: 0.6500 - lr: 1.0000e-05
# Epoch 87/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9819 - accuracy: 0.6022
# Epoch 87: val_loss did not improve from 0.88575
# 74/74 [==============================] - 74s 998ms/step - loss: 0.9819 - accuracy: 0.6022 - val_loss: 0.8970 - val_accuracy: 0.6479 - lr: 1.0000e-05
# Epoch 88/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9806 - accuracy: 0.6018
# Epoch 88: val_loss improved from 0.88575 to 0.88260, saving model to best_model.h5
# 74/74 [==============================] - 79s 1s/step - loss: 0.9806 - accuracy: 0.6018 - val_loss: 0.8826 - val_accuracy: 0.6458 - lr: 1.0000e-05
# Epoch 89/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9844 - accuracy: 0.5771
# Epoch 89: val_loss did not improve from 0.88260
# 74/74 [==============================] - 72s 963ms/step - loss: 0.9844 - accuracy: 0.5771 - val_loss: 0.8897 - val_accuracy: 0.6500 - lr: 1.0000e-05
# Epoch 90/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9863 - accuracy: 0.5920
# Epoch 90: val_loss did not improve from 0.88260
# 74/74 [==============================] - 70s 944ms/step - loss: 0.9863 - accuracy: 0.5920 - val_loss: 0.8898 - val_accuracy: 0.6542 - lr: 1.0000e-05
# Epoch 91/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9868 - accuracy: 0.5911
# Epoch 91: val_loss did not improve from 0.88260
# 74/74 [==============================] - 70s 944ms/step - loss: 0.9868 - accuracy: 0.5911 - val_loss: 0.8856 - val_accuracy: 0.6625 - lr: 1.0000e-05
# Epoch 92/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9765 - accuracy: 0.5992
# Epoch 92: val_loss did not improve from 0.88260
# 74/74 [==============================] - 70s 948ms/step - loss: 0.9765 - accuracy: 0.5992 - val_loss: 0.8850 - val_accuracy: 0.6542 - lr: 1.0000e-05
# Epoch 93/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9800 - accuracy: 0.5958
# Epoch 93: val_loss did not improve from 0.88260
# 74/74 [==============================] - 70s 939ms/step - loss: 0.9800 - accuracy: 0.5958 - val_loss: 0.8917 - val_accuracy: 0.6500 - lr: 1.0000e-05
# Epoch 94/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9710 - accuracy: 0.5933
# Epoch 94: val_loss did not improve from 0.88260
# 74/74 [==============================] - 70s 942ms/step - loss: 0.9710 - accuracy: 0.5933 - val_loss: 0.8867 - val_accuracy: 0.6396 - lr: 1.0000e-05
# Epoch 95/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9832 - accuracy: 0.5971
# Epoch 95: val_loss did not improve from 0.88260
# 74/74 [==============================] - 70s 941ms/step - loss: 0.9832 - accuracy: 0.5971 - val_loss: 0.8834 - val_accuracy: 0.6521 - lr: 1.0000e-05
# Epoch 96/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9798 - accuracy: 0.5894
# Epoch 96: val_loss did not improve from 0.88260
# 74/74 [==============================] - 71s 952ms/step - loss: 0.9798 - accuracy: 0.5894 - val_loss: 0.8845 - val_accuracy: 0.6521 - lr: 1.0000e-05
# Epoch 97/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9791 - accuracy: 0.5928
# Epoch 97: val_loss did not improve from 0.88260
# 74/74 [==============================] - 70s 947ms/step - loss: 0.9791 - accuracy: 0.5928 - val_loss: 0.8893 - val_accuracy: 0.6500 - lr: 1.0000e-05
# Epoch 98/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9898 - accuracy: 0.5895
# Epoch 98: val_loss did not improve from 0.88260
# 74/74 [==============================] - 70s 947ms/step - loss: 0.9898 - accuracy: 0.5895 - val_loss: 0.8981 - val_accuracy: 0.6438 - lr: 1.0000e-05
# Epoch 99/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9765 - accuracy: 0.5890
# Epoch 99: val_loss did not improve from 0.88260
# 74/74 [==============================] - 70s 944ms/step - loss: 0.9765 - accuracy: 0.5890 - val_loss: 0.8918 - val_accuracy: 0.6479 - lr: 1.0000e-05
# Epoch 100/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9825 - accuracy: 0.5954
# Epoch 100: val_loss did not improve from 0.88260
# 74/74 [==============================] - 71s 951ms/step - loss: 0.9825 - accuracy: 0.5954 - val_loss: 0.8833 - val_accuracy: 0.6479 - lr: 1.0000e-05
# Epoch 101/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9728 - accuracy: 0.5848
# Epoch 101: val_loss did not improve from 0.88260
# 74/74 [==============================] - 71s 960ms/step - loss: 0.9728 - accuracy: 0.5848 - val_loss: 0.8885 - val_accuracy: 0.6229 - lr: 1.0000e-05
# Epoch 102/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9753 - accuracy: 0.5967
# Epoch 102: val_loss did not improve from 0.88260
# 74/74 [==============================] - 70s 946ms/step - loss: 0.9753 - accuracy: 0.5967 - val_loss: 0.8904 - val_accuracy: 0.6313 - lr: 1.0000e-05
# Epoch 103/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9875 - accuracy: 0.5877
# Epoch 103: val_loss improved from 0.88260 to 0.87995, saving model to best_model.h5
# 74/74 [==============================] - 72s 962ms/step - loss: 0.9875 - accuracy: 0.5877 - val_loss: 0.8800 - val_accuracy: 0.6646 - lr: 1.0000e-05
# Epoch 104/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9777 - accuracy: 0.5924
# Epoch 104: val_loss improved from 0.87995 to 0.87346, saving model to best_model.h5
# 74/74 [==============================] - 72s 965ms/step - loss: 0.9777 - accuracy: 0.5924 - val_loss: 0.8735 - val_accuracy: 0.6438 - lr: 1.0000e-05
# Epoch 105/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9699 - accuracy: 0.5860
# Epoch 105: val_loss did not improve from 0.87346
# 74/74 [==============================] - 70s 949ms/step - loss: 0.9699 - accuracy: 0.5860 - val_loss: 0.8785 - val_accuracy: 0.6562 - lr: 1.0000e-05
# Epoch 106/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9787 - accuracy: 0.5971
# Epoch 106: val_loss did not improve from 0.87346
# 74/74 [==============================] - 71s 959ms/step - loss: 0.9787 - accuracy: 0.5971 - val_loss: 0.8783 - val_accuracy: 0.6625 - lr: 1.0000e-05
# Epoch 107/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9771 - accuracy: 0.5874
# Epoch 107: val_loss did not improve from 0.87346
# 74/74 [==============================] - 70s 948ms/step - loss: 0.9771 - accuracy: 0.5874 - val_loss: 0.8844 - val_accuracy: 0.6375 - lr: 1.0000e-05
# Epoch 108/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9687 - accuracy: 0.5886
# Epoch 108: val_loss did not improve from 0.87346
# 74/74 [==============================] - 71s 962ms/step - loss: 0.9687 - accuracy: 0.5886 - val_loss: 0.8760 - val_accuracy: 0.6667 - lr: 1.0000e-05
# Epoch 109/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9655 - accuracy: 0.6065
# Epoch 109: val_loss did not improve from 0.87346
# 74/74 [==============================] - 71s 950ms/step - loss: 0.9655 - accuracy: 0.6065 - val_loss: 0.8762 - val_accuracy: 0.6542 - lr: 1.0000e-05
# Epoch 110/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9641 - accuracy: 0.6065
# Epoch 110: val_loss improved from 0.87346 to 0.86869, saving model to best_model.h5
# 74/74 [==============================] - 71s 962ms/step - loss: 0.9641 - accuracy: 0.6065 - val_loss: 0.8687 - val_accuracy: 0.6667 - lr: 1.0000e-05
# Epoch 111/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9676 - accuracy: 0.5967
# Epoch 111: val_loss did not improve from 0.86869
# 74/74 [==============================] - 71s 952ms/step - loss: 0.9676 - accuracy: 0.5967 - val_loss: 0.8762 - val_accuracy: 0.6708 - lr: 1.0000e-05
# Epoch 112/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9642 - accuracy: 0.6014
# Epoch 112: val_loss did not improve from 0.86869
# 74/74 [==============================] - 70s 936ms/step - loss: 0.9642 - accuracy: 0.6014 - val_loss: 0.8792 - val_accuracy: 0.6604 - lr: 1.0000e-05
# Epoch 113/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9625 - accuracy: 0.6031
# Epoch 113: val_loss did not improve from 0.86869
# 74/74 [==============================] - 72s 967ms/step - loss: 0.9625 - accuracy: 0.6031 - val_loss: 0.8840 - val_accuracy: 0.6500 - lr: 1.0000e-05
# Epoch 114/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9728 - accuracy: 0.5860
# Epoch 114: val_loss improved from 0.86869 to 0.85918, saving model to best_model.h5
# 74/74 [==============================] - 71s 958ms/step - loss: 0.9728 - accuracy: 0.5860 - val_loss: 0.8592 - val_accuracy: 0.6583 - lr: 1.0000e-05
# Epoch 115/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9627 - accuracy: 0.6107
# Epoch 115: val_loss did not improve from 0.85918
# 74/74 [==============================] - 73s 978ms/step - loss: 0.9627 - accuracy: 0.6107 - val_loss: 0.8798 - val_accuracy: 0.6354 - lr: 1.0000e-05
# Epoch 116/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9606 - accuracy: 0.6060
# Epoch 116: val_loss did not improve from 0.85918
# 74/74 [==============================] - 71s 950ms/step - loss: 0.9606 - accuracy: 0.6060 - val_loss: 0.8739 - val_accuracy: 0.6417 - lr: 1.0000e-05
# Epoch 117/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9587 - accuracy: 0.6082
# Epoch 117: val_loss did not improve from 0.85918
# 74/74 [==============================] - 70s 945ms/step - loss: 0.9587 - accuracy: 0.6082 - val_loss: 0.8660 - val_accuracy: 0.6625 - lr: 1.0000e-05
# Epoch 118/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9661 - accuracy: 0.5928
# Epoch 118: val_loss did not improve from 0.85918
# 74/74 [==============================] - 70s 944ms/step - loss: 0.9661 - accuracy: 0.5928 - val_loss: 0.8700 - val_accuracy: 0.6604 - lr: 1.0000e-05
# Epoch 119/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9619 - accuracy: 0.6039
# Epoch 119: val_loss did not improve from 0.85918
# 74/74 [==============================] - 72s 974ms/step - loss: 0.9619 - accuracy: 0.6039 - val_loss: 0.8659 - val_accuracy: 0.6417 - lr: 1.0000e-05
# Epoch 120/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9631 - accuracy: 0.5971
# Epoch 120: val_loss did not improve from 0.85918
# 74/74 [==============================] - 75s 1s/step - loss: 0.9631 - accuracy: 0.5971 - val_loss: 0.8651 - val_accuracy: 0.6542 - lr: 1.0000e-05
# Epoch 121/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9607 - accuracy: 0.6039
# Epoch 121: val_loss did not improve from 0.85918
# 74/74 [==============================] - 72s 968ms/step - loss: 0.9607 - accuracy: 0.6039 - val_loss: 0.8695 - val_accuracy: 0.6792 - lr: 1.0000e-05
# Epoch 122/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9679 - accuracy: 0.5950
# Epoch 122: val_loss did not improve from 0.85918
# 74/74 [==============================] - 69s 933ms/step - loss: 0.9679 - accuracy: 0.5950 - val_loss: 0.8663 - val_accuracy: 0.6667 - lr: 1.0000e-05
# Epoch 123/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9653 - accuracy: 0.6026
# Epoch 123: val_loss did not improve from 0.85918
# 74/74 [==============================] - 70s 942ms/step - loss: 0.9653 - accuracy: 0.6026 - val_loss: 0.8715 - val_accuracy: 0.6604 - lr: 1.0000e-05
# Epoch 124/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9549 - accuracy: 0.5963
# Epoch 124: val_loss did not improve from 0.85918
# 74/74 [==============================] - 70s 944ms/step - loss: 0.9549 - accuracy: 0.5963 - val_loss: 0.8742 - val_accuracy: 0.6562 - lr: 1.0000e-05
# Epoch 125/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9736 - accuracy: 0.5924
# Epoch 125: val_loss did not improve from 0.85918
# 74/74 [==============================] - 70s 944ms/step - loss: 0.9736 - accuracy: 0.5924 - val_loss: 0.8641 - val_accuracy: 0.6646 - lr: 1.0000e-05
# Epoch 126/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9589 - accuracy: 0.6090
# Epoch 126: val_loss did not improve from 0.85918
# 74/74 [==============================] - 71s 951ms/step - loss: 0.9589 - accuracy: 0.6090 - val_loss: 0.8676 - val_accuracy: 0.6562 - lr: 1.0000e-05
# Epoch 127/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9496 - accuracy: 0.6112
# Epoch 127: val_loss did not improve from 0.85918
# 74/74 [==============================] - 70s 948ms/step - loss: 0.9496 - accuracy: 0.6112 - val_loss: 0.8595 - val_accuracy: 0.6625 - lr: 1.0000e-05
# Epoch 128/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9571 - accuracy: 0.5937
# Epoch 128: val_loss did not improve from 0.85918
# 74/74 [==============================] - 70s 946ms/step - loss: 0.9571 - accuracy: 0.5937 - val_loss: 0.8786 - val_accuracy: 0.6562 - lr: 1.0000e-05
# Epoch 129/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9539 - accuracy: 0.6141
# Epoch 129: val_loss did not improve from 0.85918
# 74/74 [==============================] - 70s 942ms/step - loss: 0.9539 - accuracy: 0.6141 - val_loss: 0.8626 - val_accuracy: 0.6646 - lr: 1.0000e-05
# Epoch 130/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9574 - accuracy: 0.6163
# Epoch 130: val_loss did not improve from 0.85918
# 74/74 [==============================] - 70s 939ms/step - loss: 0.9574 - accuracy: 0.6163 - val_loss: 0.8671 - val_accuracy: 0.6667 - lr: 1.0000e-05
# Epoch 131/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9612 - accuracy: 0.5992
# Epoch 131: val_loss did not improve from 0.85918
# 74/74 [==============================] - 73s 980ms/step - loss: 0.9612 - accuracy: 0.5992 - val_loss: 0.8693 - val_accuracy: 0.6604 - lr: 1.0000e-05
# Epoch 132/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9645 - accuracy: 0.5950
# Epoch 132: val_loss did not improve from 0.85918
# 74/74 [==============================] - 72s 967ms/step - loss: 0.9645 - accuracy: 0.5950 - val_loss: 0.8603 - val_accuracy: 0.6667 - lr: 1.0000e-05
# Epoch 133/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9603 - accuracy: 0.6120
# Epoch 133: val_loss improved from 0.85918 to 0.85580, saving model to best_model.h5
# 74/74 [==============================] - 73s 979ms/step - loss: 0.9603 - accuracy: 0.6120 - val_loss: 0.8558 - val_accuracy: 0.6687 - lr: 1.0000e-05
# Epoch 134/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9552 - accuracy: 0.5992
# Epoch 134: val_loss did not improve from 0.85580
# 74/74 [==============================] - 71s 958ms/step - loss: 0.9552 - accuracy: 0.5992 - val_loss: 0.8612 - val_accuracy: 0.6729 - lr: 1.0000e-05
# Epoch 135/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9589 - accuracy: 0.6082
# Epoch 135: val_loss improved from 0.85580 to 0.85536, saving model to best_model.h5
# 74/74 [==============================] - 75s 1s/step - loss: 0.9589 - accuracy: 0.6082 - val_loss: 0.8554 - val_accuracy: 0.6646 - lr: 1.0000e-05
# Epoch 136/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9488 - accuracy: 0.6171
# Epoch 136: val_loss did not improve from 0.85536
# 74/74 [==============================] - 74s 991ms/step - loss: 0.9488 - accuracy: 0.6171 - val_loss: 0.8563 - val_accuracy: 0.6583 - lr: 1.0000e-05
# Epoch 137/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9453 - accuracy: 0.6099
# Epoch 137: val_loss did not improve from 0.85536
# 74/74 [==============================] - 71s 961ms/step - loss: 0.9453 - accuracy: 0.6099 - val_loss: 0.8651 - val_accuracy: 0.6687 - lr: 1.0000e-05
# Epoch 138/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9502 - accuracy: 0.6043
# Epoch 138: val_loss did not improve from 0.85536
# 74/74 [==============================] - 73s 977ms/step - loss: 0.9502 - accuracy: 0.6043 - val_loss: 0.8607 - val_accuracy: 0.6771 - lr: 1.0000e-05
# Epoch 139/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9545 - accuracy: 0.6052
# Epoch 139: val_loss did not improve from 0.85536
# 74/74 [==============================] - 72s 973ms/step - loss: 0.9545 - accuracy: 0.6052 - val_loss: 0.8635 - val_accuracy: 0.6625 - lr: 1.0000e-05
# Epoch 140/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9642 - accuracy: 0.6048
# Epoch 140: val_loss did not improve from 0.85536
# 74/74 [==============================] - 72s 972ms/step - loss: 0.9642 - accuracy: 0.6048 - val_loss: 0.8603 - val_accuracy: 0.6708 - lr: 1.0000e-05
# Epoch 141/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9482 - accuracy: 0.6244
# Epoch 141: val_loss did not improve from 0.85536
# 74/74 [==============================] - 75s 1s/step - loss: 0.9482 - accuracy: 0.6244 - val_loss: 0.8620 - val_accuracy: 0.6521 - lr: 1.0000e-05
# Epoch 142/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9469 - accuracy: 0.6107
# Epoch 142: val_loss did not improve from 0.85536
# 74/74 [==============================] - 74s 990ms/step - loss: 0.9469 - accuracy: 0.6107 - val_loss: 0.8601 - val_accuracy: 0.6646 - lr: 1.0000e-05
# Epoch 143/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9478 - accuracy: 0.6210
# Epoch 143: val_loss improved from 0.85536 to 0.85062, saving model to best_model.h5
# 74/74 [==============================] - 76s 1s/step - loss: 0.9478 - accuracy: 0.6210 - val_loss: 0.8506 - val_accuracy: 0.6458 - lr: 1.0000e-05
# Epoch 144/150
# 74/74 [==============================] - ETA: 0s - loss: 0.9411 - accuracy: 0.6175
# Epoch 144: val_loss did not improve from 0.85062
# 74/74 [==============================] - 73s 982ms/step - loss: 0.9411 - accuracy: 0.6175 - val_loss: 0.8655 - val_accuracy: 0.6625 - lr: 1.0000e-05
# Epoch 145/150
# 23/74 [========>.....................] - ETA: 49s - loss: 0.9453 - accuracy: 0.6061
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [51], in <cell line: 1>()
# ----> 1 history = model.fit(
#       2     train_generator,
#       3     steps_per_epoch=train_generator.samples // batch_size,
#       4     epochs=epochs,
#       5     validation_data=validation_generator,
#       6     validation_steps=validation_generator.samples // batch_size,
#       7     callbacks=[model_checkpoint, early_stopping, lrr]
#       8 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py:1384, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1377 with tf.profiler.experimental.Trace(
#    1378     'train',
#    1379     epoch_num=epoch,
#    1380     step_num=step,
#    1381     batch_size=batch_size,
#    1382     _r=1):
#    1383   callbacks.on_train_batch_begin(step)
# -> 1384   tmp_logs = self.train_function(iterator)
#    1385   if data_handler.should_sync:
#    1386     context.async_wait()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\function.py:2956, in Function.__call__(self, *args, **kwargs)
#    2953 with self._lock:
#    2954   (graph_function,
#    2955    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2956 return graph_function._call_flat(
#    2957     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\function.py:1853, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1849 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1850 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1851     and executing_eagerly):
#    1852   # No tape is watching; skip to running the function.
# -> 1853   return self._build_call_outputs(self._inference_function.call(
#    1854       ctx, args, cancellation_manager=cancellation_manager))
#    1855 forward_backward = self._select_forward_and_backward_functions(
#    1856     args,
#    1857     possible_gradient_type,
#    1858     executing_eagerly)
#    1859 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
from tensorflow import keras

loaded_model = keras.models.load_model('best_model.h5')

# %%
test_loss, test_accuracy = loaded_model.evaluate(test_generator)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")

# %%
y_pred = loaded_model.predict(test_generator)
y_true = test_generator.classes

# Generate a classification report
target_names = list(test_generator.class_indices.keys())
classification_rep = classification_report(y_true, y_pred.argmax(axis=1), target_names=target_names)
print("Classification Report:\n", classification_rep)

# %%
# Plot the loss and accuracy graphs
plt.figure(figsize=(12, 4))

# Plot training & validation loss values
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation accuracy values
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %%
f1_macro = f1_score(y_true, y_pred.argmax(axis=1), average='macro')
f1_weighted = f1_score(y_true, y_pred.argmax(axis=1), average='weighted')

print(f"Weighted F1 Score: {f1_weighted:.4f}")
print(f"Macro F1 Score: {f1_macro:.4f}")
